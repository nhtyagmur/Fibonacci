# %% [markdown]
# <a href="https://colab.research.google.com/github/nhtyagmur/Fibonacci/blob/master/Integration2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %%
import sympy as sy

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x=sy.symbols("x")
y=sy.symbols("y")
a=sy.symbols("a")

# %%
x=np.linspace(-1,4,100)
y=x**4-4*x**3+10

# %%
plt.plot(x,y)

# %%
x=np.linspace(-5,5,100)
y=((x+1)**2)/(1+x**2)

# %%
plt.plot(x,y)

# %%
sy.integrate((1-x**3)**2,(x,0,1))
# Out:
# 9/14

# %%
n=sy.symbols("n")
x=sy.symbols("x")

# %%
sy.integrate(1/x**n, (x,1,sy.oo))
# Out:
# Piecewise((1/(n - 1), re(n) > 1), (Integral(x**(-n), (x, 1, oo)), True))

# %%
x=np.linspace(0.00001,5,100)
y=np.log(x)

# %%
plt.plot(x,y)

# %%
sy.integrate(sy.ln(x), (x,0,1))
# Out:
# -1

# %%
g=sy.diff(x/(x+2),x)
g
# Out:
# -x/(x + 2)**2 + 1/(x + 2)

# %%
round(sy.integrate(g,(x,1,3)).evalf(),2)
# Out:
# 0.27

# %%
R=sy.symbols("R")
x=sy.symbols("x")

# %%
sy.integrate(1/x**2, (x,R,sy.oo))
# Out:
# 1/R

# %%
6.67*5.97/6.37
# Out:
# 6.251161695447409

# %%
round(sy.sqrt(2*6.67*5.97/6.37*10**7))
# Out:
# 11181
