# %% [markdown]
# <a href="https://colab.research.google.com/github/nhtyagmur/Fibonacci/blob/master/Differentiation2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %%
import sympy as sy

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x=sy.symbols("x")

# %%
f=sy.exp(x)*sy.sin(x)
f
# Out:
# exp(x)*sin(x)

# %%
sy.diff(f,x)
# Out:
# exp(x)*sin(x) + exp(x)*cos(x)

# %%
x=np.linspace(0,2*np.pi,1000)
y=np.exp(x)*np.sin(x)+np.exp(x)*np.cos(x)

# %%
plt.plot(x,y)

# %%
x=np.linspace(0.6,1.6,100)
g=np.sin(np.pi*x-0.1*np.pi)

# %%
plt.plot(x,g)

# %%
g=sy.sin(sy.pi*x-0.1*sy.pi)
g
# Out:
# sin(pi*x - 0.1*pi)

# %%
sy.diff(g,x)
# Out:
# pi*cos(pi*x - 0.1*pi)

# %%
sy.solve(sy.diff(g,x))
# Out:
# [-0.400000000000000, 0.600000000000000]

# %%
sy.solve(sy.pi*x-0.1*sy.pi-3*sy.pi/2)
# Out:
# [1.60000000000000]

# %%
[0.6,1.6]
# Out:
# [0.6, 1.6]

# %%
f=sy.sin(x)/x
f
# Out:
# sin(x)/x

# %%
sy.limit(f,x,0)
# Out:
# 1

# %%
sy.limit(sy.sin(x)/x,x,sy.oo)
# Out:
# 0

# %%
x=np.linspace(0,2*np.pi,100)
y=np.sin(x)

# %%
plt.plot(x,y)
